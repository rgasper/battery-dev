# %%
import pandas as pd
import seaborn as sb

# %%
df = pd.read_csv('../data/current.csv', index_col='timestamp')
sb.lineplot(data=df)
# Out:
# <AxesSubplot:xlabel='timestamp'>

# %%
df = pd.read_csv('../data/voltage.csv', index_col='timestamp')
sb.lineplot(data=df)
# Out:
# <AxesSubplot:xlabel='timestamp'>
